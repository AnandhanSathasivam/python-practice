# %%
numbers =[1,2,3,4,5]

# %%
squares =[]

for num in numbers:
    squares.append(num ** 2)

# %%
print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
squares1 = []
numbers2 = [2,4,6,8,10]
squares1 = [num1 ** 2 for num1 in numbers2]

# %%
print(squares1)
# Out:
# [4, 16, 36, 64, 100]

# %% [markdown]
# ## Even numbers if condition

# %%
numbers3 =[1,2,3,4,5,6,7,8,9]
even = [x for x in numbers3 if x % 2 == 0]
print(even)
# Out:
# [2, 4, 6, 8]
